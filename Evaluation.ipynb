# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os
import random as rn
from sklearn.metrics.pairwise import cosine_similarity
import networkx as nx
from datetime import datetime as dt
from datetime import timedelta


# %run Functions.ipynb

# %%
method = ['Method 1','Method 2','Baseline 1','Baseline 2','Baseline 3',
            'Baseline 4a','Baseline 4b','Baseline 5','Baseline 6']

# %% [markdown]
# # Exit point evaluation

# %%
f = 20 
plt.figure(figsize = (15,10))

for m in method:
    prediction = pd.read_csv("Prediction - "+m+" exit points.csv").drop(['Unnamed: 0'],axis=1)
    # Precision
    precision = Precision(prediction)
    precision_plot(precision,m)
_ = plt.legend(fontsize=f)
_ = plt.xticks(fontsize=f)
_ = plt.yticks(fontsize=f)

plt.savefig("Graphs - precision plot aggregated for exit points.png")


i = 1
plt.figure(figsize = (30,30))
for m in method:
    prediction = pd.read_csv("Prediction - "+m+" exit points.csv").drop(['Unnamed: 0'],axis=1)
    
    #Recall
    recall = Recall(prediction,m)
    recall = recall.sort_values('p')
    plt.subplot(3,3,i)
    sns.barplot(x=recall['p'].astype(str),y=recall['recall'],hue = recall['k'])
    i = i+1
    
    _ = plt.legend(fontsize=f)
    _ = plt.xlabel(' ',fontsize=f)
    _ = plt.ylabel('',fontsize=f)
    _ = plt.xticks(fontsize=f)        


    _ = plt.yticks(fontsize=f)
    _ = plt.title(m,fontsize=f)

plt.savefig("Graphs - recall plot aggregated for exit points.png")
# Out:
# <ipython-input-1-90dad8653abc>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred['actual'] = prediction['actual']
# <ipython-input-1-90dad8653abc>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred['actual'] = prediction['actual']
# <ipython-input-1-90dad8653abc>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
f = 20 
plt.figure(figsize = (15,10))

for m in method:
    prediction = pd.read_csv("Prediction - "+m+" interim points.csv").drop(['Unnamed: 0'],axis=1)
    # Precision
    precision = Precision(prediction)
    precision_plot(precision,m)
_ = plt.legend(fontsize=f)
_ = plt.xticks(fontsize=f)
_ = plt.yticks(fontsize=f)

plt.savefig("Graphs - precision plot aggregated for interim points.png")



i = 1
plt.figure(figsize = (30,30))
for m in method:
    prediction = pd.read_csv("Prediction - "+m+" interim points.csv").drop(['Unnamed: 0'],axis=1)
    
    #Recall
    recall = Recall(prediction,m)
    recall = recall.sort_values('p')
    plt.subplot(3,3,i)
    sns.barplot(x=recall['p'].astype(str),y=recall['recall'],hue = recall['k'])
    i = i+1
    
    _ = plt.legend(fontsize=f)
    _ = plt.xlabel(' ',fontsize=f)
    _ = plt.ylabel('',fontsize=f)
    _ = plt.xticks(fontsize=f)        


    _ = plt.yticks(fontsize=f)
    _ = plt.title(m,fontsize=f)

plt.savefig("Graphs - recall plot aggregated for interim points.png")
# Out:
# <ipython-input-1-90dad8653abc>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred['actual'] = prediction['actual']
# <ipython-input-1-90dad8653abc>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred['actual'] = prediction['actual']
# <ipython-input-1-90dad8653abc>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
